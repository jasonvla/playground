# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.read_graphml(r"C:\Users\burge\Desktop\Uni\Digitale Netzwerkanalyse\RadioheadX.graphml")
all_nodes = G.nodes()
allweights = 0
for (node1,node2,data) in G.edges(data=True):
    edgeweights_list = [list(data.values())[0]]
    for weights in edgeweights_list:
        allweights += weights
print(allweights * 2 / len(all_nodes))
# Out:
# 208.07303370786516
